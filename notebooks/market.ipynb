# %%
from sentiment.sources.alpaca import AlpacaSource
from sentiment.sources.cache import MarketDataCache
from datetime import datetime
# Out:
# C:\ProgramData\anaconda3\envs\260310_TFAproject\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
alpaca = AlpacaSource()

# %%
symbols = ["AAPL"]
timeframe = "1Day"
start = datetime(2025, 1, 1)
end = datetime(2025, 12, 31)

# %%
df = alpaca.fetch_bars(
    symbols,
    timeframe,
    start,
    end,
)

# %%
df.head()
# Out:
#                           symbol    open      high       low   close  \
# timestamp
# 2025-01-02 05:00:00+00:00   AAPL  248.93  249.1000  241.8201  243.85
# 2025-01-03 05:00:00+00:00   AAPL  243.36  244.1800  241.8900  243.36
# 2025-01-06 05:00:00+00:00   AAPL  244.31  247.3300  243.2000  245.00
# 2025-01-07 05:00:00+00:00   AAPL  242.98  245.5500  241.3500  242.21
# 2025-01-08 05:00:00+00:00   AAPL  241.92  243.7123  240.0500  242.70
#
#                              volume  trade_count        vwap
# timestamp
# 2025-01-02 05:00:00+00:00  55740731       685448  244.339399
# 2025-01-03 05:00:00+00:00  40244114       493786  243.069441
# 2025-01-06 05:00:00+00:00  45045571       493920  245.239060
# 2025-01-07 05:00:00+00:00  40855960       462887  243.011137
# 2025-01-08 05:00:00+00:00  37628940       406916  242.272854

# %%
cache = MarketDataCache()

# %%
cache.store("AAPL", 2025, df)
